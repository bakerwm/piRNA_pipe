# %% [markdown]
# # Documentation - piRNA pipe
#
#
#
#
# ## 1 Purpose
#
# For small RNA seqeuencing analysis (total, piwi-IP seq, etc).
#
#
#
#
# ## 2 workflow
#
#
# ### 2.1 pre-analysis
#
# + Main steps
#
#   - remove structural RNAs (rRNA, tRNA, snRNA, snoRNA, ..., check rRNA%)
#   - remove miRNAs (miRNA hairpin, 0 mismatch, unique + multi)
#   - split by length ([23,29], others)
#   - map to TE consensus (0 mismatch, unique)
#   - map to piRNA clusters (0 mismatch, unique)
#   - map to genome (0 mismatch, unique + multi)
#
# + Extra
#
#   - read size distribution
#   - evaluate 1U-10A
#   - check overlap between samples
#
# + To-do
#
#   - extract siRNAs (21nt)
#   - ping-pong signature score
#   - correlation between samples
#   - compare with piRBase (v2.0), other published data
#
#
#
#
# ## 3 Analysis
#
#
# ### 3.1 main
#
#   - `piRNA_pipe.py`
#
#
#
# ### 3.2 modules
#
#   - `fragsize.py` - calculate the distribution of read length
#
#   - `u1a10.py` - calculate the U1A10 content
#
#   - `fx_overlap.py` - check the overlap between two fastx file
#
#
#
#
#
# ### 3.3 Directory structure
#
# ```
# ├── 00.raw_data
# ├── 01.clean_data
# ├── 02.collapse
# ├── 03.overlap
# ├── 04.smRNA
# ├── 05.miRNA
# ├── 06.size_exclude
# ├── 06.size_select
# ├── 07.te
# ├── 08.piRNA_cluster
# ├── 09.genome
# ├── 10.unmap
# ├── 11.stat
# └── 12.report
#
# ```
#
#
# ### 3.4 Output files
#
#
#
#
# ## x. Change log
#
#
#
#
# ```
# piRNA analysis (small RNAseq)
#
#
# date: 2020-12-27
#
# 1. support collapsed reads, counting, RNA seqs, reads
#
#
# date: 2020-12-23
# Author: Ming Wang
#
# # flowchart of piRNA analysis
# 1. remove structural RNAs (uniqe + multi)
# 2. remove miRNAs (unique + multi)
# 3. remove reads not in [23-29] nt
# 4. collapse reads: consider 1-23nt only, allow 1-2 at 3' differ (2019-11-26)
# 5. split into 4 groups: (1U+/-,10A+/-;)
# 6. map to TE consensus, (unique + multi), only 1U_not_10A
# 7. map to genome (unique + multi)
# Functions:
# rename fastq reads: piR0000001-0000001
# piR (piRNA), (piRNA number) {reads number}
# mapping, unique + multiple/unique
#
#
# version: 2020-07-28
# update:
# 1. remove temp fastq files
# 2. gzip fastq files
#
# version: 2020-07-25
# update:
# 1. collapse reads
#
#
# date: 2020-07-23
# in brief:
#
# 1. remove 3' adapters
# 2. remove structural RNAs (tRNAs, rRNAs) (unique + multiple)
# 3. filt by length, 23-29 nt
# 4. collapse reads, only compare 1-23 nt (*)
#    collapse reads, (regular)
#    trim reads to 23nt from 3' end
#
# 5. map to TE consensus (unique, multiple, unique + multiple)
# 6. map to piRNA clusters (unique, multiple, unique + multiple)
# 7. map to genome (not-TE, no-piRNAcluster)
# 8. Overall, map to genome
# ```

# %%
# %reload_ext autoreload
# %autoreload 2
from piRNA_pipe import *

args = {
    'fq': 'test/a.fq.gz',
    'outdir': 'test/results',
    'collapse': True,
    'subject': 'test/b.fq.gz',
    'force_overlap': True,
    'ov_type': 1,
}
# p = pipe(**args).run()

args = {
    'query': 'test/a.fq',
    'subject': 'test/b.fq',
    'outdir': 'test/overlap',
    'mm': 2
}
OverlapFq(**args).run()
# overlap_fq('test/a.fq', 'test/b.fq', 'test/overlap2')

# %%
# U1A10

# %reload_ext autoreload
# %autoreload 2
from fastx import *

fx = ['test/a.fq.gz', 'test/b.fq.gz']

FxU1A10(fx).run()

# %%
# Alignemt
# %reload_ext autoreload
# %autoreload 2
import pyfastx
from align import *

args = {
    'fx': 'test/a.fq.gz',
    'index': '/data/yulab/wangming/data/genome/dm6/bowtie_index/miRNA',
    'outdir': 'test/bbbbbb',
    'unique': 'multi'
}

Align(**args).run()

# %%
# PiRNApipe

# %reload_ext autoreload
# %autoreload 2
import pyfastx
from piRNA_pipe import *

args = {
    'fq': 'test/b.fq.gz',
    'outdir': 'test/aaaaaa',
    'genome': 'dm6',
    'subject_list': 'test/a.fq.gz'
}

p1 = PiRNApipe(**args)
p1.run()
p2 = overlap_subject(p1)
# Out:
# --------------------------------------------------------------------------------
#              fq: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/b.fq.gz
#          outdir: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa
#        smp_name: b
#          genome: dm6
#         subject: None
#         overlap: no
# --------------------------------------------------------------------------------
# Check the bowtie indexes:
#     smRNA_index: ok     /home/wangming/data/genome/dm6/bowtie_index/smRNA
#     miRNA_index: ok     /home/wangming/data/genome/dm6/bowtie_index/hairpin
#        te_index: ok     /home/wangming/data/genome/dm6/bowtie_index/te
#      piRC_index: ok     /home/wangming/data/genome/dm6/bowtie_index/piRNA_cluster
#    genome_index: ok     /home/wangming/data/genome/dm6/bowtie_index/dm6
# --------------------------------------------------------------------------------
# [2021-03-05 10:02:33 INFO] 00.Copy raw data
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/b.fastq.gz
# [2021-03-05 10:02:33 INFO] 01.Trim adapters
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/b.fastq.gz
# [2021-03-05 10:02:33 INFO] 02.Collapse fastq
# [2021-03-05 10:02:33 INFO] collapse_fx() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/b.fastq.gz
# [2021-03-05 10:02:33 INFO] 03.Overlap with other RNAs
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/b.fastq.gz
# [2021-03-05 10:02:33 INFO] 04.Map to small RNA
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/both/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/b.fastq.gz
# [2021-03-05 10:02:33 INFO] 05.Map to miRNA
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/both/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/b.fastq.gz
# [2021-03-05 10:02:33 INFO] 06.Size select
# [2021-03-05 10:02:33 INFO] file exists, split_fx() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/both/b.unmap.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/b.fastq.gz
# [2021-03-05 10:02:33 INFO] 07.map to TE
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/both/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/b.fastq.gz
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/unique/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/b.fastq.gz
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/multi/tmp/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] file exists, align skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/multi/b.fastq
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/multi/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/b.fastq.gz
# [2021-03-05 10:02:33 INFO] 08.Map to piRNA cluster
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/both/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/b.fastq.gz
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/unique/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/b.fastq.gz
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/multi/tmp/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] file exists, align skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/multi/b.fastq
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/multi/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/b.fastq.gz
# [2021-03-05 10:02:33 INFO] 09.Map to genome
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/both/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/b.fastq.gz
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/unique/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/b.fastq.gz
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/multi/tmp/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] file exists, align skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/multi/b.fastq
# [2021-03-05 10:02:33 INFO] file exixts, align() skipped: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/multi/b.bam
# [2021-03-05 10:02:33 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/b.fastq.gz
# [2021-03-05 10:02:33 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/both/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/both/b.unmap.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/both/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/both/b.unmap.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/both/b.unmap.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/both/b.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/both/b.unmap.fastq.gz
# [2021-03-05 10:02:33 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/unique/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/both/b.unmap.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/both/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/both/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/unique/b.unmap.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/unique/b.unmap.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/unique/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/multi/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/multi/b.unmap.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/multi/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/unique/b.unmap.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/multi/b.unmap.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/multi/b.unmap.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/unique/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxU1A10() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/multi/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/b.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:34 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/U1_A10/b.V1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/U1_A10/b.U1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/U1_A10/b.U1_B10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/U1_A10/b.V1_A10.fastq.gz
# [2021-03-05 10:02:35 INFO] FxCount() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/U1_A10/b.V1_B10.fastq.gz
# fx_name	fx_type	unique	total
# b	4680	fastq	4680
# b	4680	fastq	4680
# b	3907	fastq	3907
# b	3907	fastq	3907
# b	66	fastq	66
# b	107	fastq	107
# b	957	fastq	957
# b	2777	fastq	2777
# b	1277	fastq	1277
# b	562	fastq	562
# b	480	fastq	480
# b	458	fastq	458
# b.U1_A10	770	fastq	770
# b.U1_B10	2222	fastq	2222
# b.V1_A10	478	fastq	478
# b.V1_B10	1210	fastq	1210
# b.U1_A10	770	fastq	770
# b.U1_B10	2222	fastq	2222
# b.V1_A10	478	fastq	478
# b.V1_B10	1210	fastq	1210
# b.U1_A10	664	fastq	664
# b.U1_B10	1793	fastq	1793
# b.V1_A10	379	fastq	379
# b.V1_B10	1071	fastq	1071
# b.U1_A10	664	fastq	664
# b.U1_B10	1793	fastq	1793
# b.V1_A10	379	fastq	379
# b.V1_B10	1071	fastq	1071
# b.U1_A10	8	fastq	8
# b.U1_B10	34	fastq	34
# b.V1_A10	11	fastq	11
# b.V1_B10	13	fastq	13
# b.U1_A10	16	fastq	16
# b.U1_B10	51	fastq	51
# b.V1_A10	13	fastq	13
# b.V1_B10	27	fastq	27
# b.U1_A10	81	fastq	81
# b.U1_B10	258	fastq	258
# b.V1_A10	131	fastq	131
# b.V1_B10	487	fastq	487
# b.U1_A10	559	fastq	559
# b.U1_B10	1450	fastq	1450
# b.V1_A10	224	fastq	224
# b.V1_B10	544	fastq	544
# b.U1_A10	254	fastq	254
# b.U1_B10	738	fastq	738
# b.V1_A10	79	fastq	79
# b.V1_B10	206	fastq	206
# b.U1_A10	122	fastq	122
# b.U1_B10	310	fastq	310
# b.V1_A10	35	fastq	35
# b.V1_B10	95	fastq	95
# b.U1_A10	101	fastq	101
# b.U1_B10	228	fastq	228
# b.V1_A10	53	fastq	53
# b.V1_B10	98	fastq	98
# b.U1_A10	82	fastq	82
# b.U1_B10	174	fastq	174
# b.V1_A10	57	fastq	57
# b.V1_B10	145	fastq	145
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/b.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/01.clean_data/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/03.overlap/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/04.smRNA/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/05.miRNA/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_select/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/07.te/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/06.size_exclude/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/09.genome/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/08.piRNA_cluster/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/10.unmap/U1_A10/b.V1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/U1_A10/b.U1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/U1_A10/b.U1_B10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/U1_A10/b.V1_A10.fragsize.csv
# [2021-03-05 10:02:35 INFO] fragsize() skipped, file exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/00.raw_data/U1_A10/b.V1_B10.fragsize.csv
# !AAAA-2
# !AAAA-3
# --------------------------------------------------------------------------------
#              fq: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/02.collapse/b.fastq.gz
#          outdir: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a
#        smp_name: b
#          genome: dm6
#         subject: test/a.fq.gz
#         overlap: yes
# --------------------------------------------------------------------------------
# Check the bowtie indexes:
#     smRNA_index: ok     /home/wangming/data/genome/dm6/bowtie_index/smRNA
#     miRNA_index: ok     /home/wangming/data/genome/dm6/bowtie_index/hairpin
#        te_index: ok     /home/wangming/data/genome/dm6/bowtie_index/te
#      piRC_index: ok     /home/wangming/data/genome/dm6/bowtie_index/piRNA_cluster
#    genome_index: ok     /home/wangming/data/genome/dm6/bowtie_index/dm6
# --------------------------------------------------------------------------------
# [2021-03-05 10:02:36 INFO] 00.Copy raw data
# [2021-03-05 10:02:36 INFO] 01.Trim adapters
# [2021-03-05 10:02:36 INFO] 02.Collapse fastq
# [2021-03-05 10:02:36 INFO] 03.Overlap with other RNAs
# [2021-03-05 10:02:36 INFO] run_shell_cmd: PID=540122, PGID=540122, CMD=seqkit common -s -j 4 /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a/b/02.collapse/b.fastq.gz test/a.fq.gz 2> /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a/b/03.overlap/cmd.log | pigz -p 4 > /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a/b/03.overlap/b.fastq.gz
# query: 3907, overlap: 3907, percent: 100.00%
# [2021-03-05 10:02:36 INFO] 04.Map to small RNA
# [2021-03-05 10:02:36 INFO] 05.Map to miRNA
# [2021-03-05 10:02:36 INFO] 06.Size select
# [2021-03-05 10:02:36 INFO] 07.map to TE
# [2021-03-05 10:02:37 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a/b/07.te/b.fastq.gz
# [2021-03-05 10:02:37 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:37 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a/b/07.te/b.fastq.gz
# [2021-03-05 10:02:37 INFO] 08.Map to piRNA cluster
# [2021-03-05 10:02:37 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a/b/08.piRNA_cluster/b.fastq.gz
# [2021-03-05 10:02:38 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:38 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a/b/08.piRNA_cluster/b.fastq.gz
# [2021-03-05 10:02:38 INFO] 09.Map to genome
# [2021-03-05 10:02:38 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a/b/09.genome/b.fastq.gz
# [2021-03-05 10:02:39 INFO] file exists, bam_to_fq() skipped: b.fastq.gz
# [2021-03-05 10:02:39 INFO] symlink() skipped, dest exists: /data/yulab/wangming/work/devel_pipeline/pirna_seq/scripts/test/aaaaaa/b/overlap/a/b/09.genome/b.fastq.gz
# fx_name	fx_type	unique	total
# b	fastq	3907	3907
# b	fastq	3907	3907
# b	fastq	3907	3907
# b	fastq	3907	3907
# b	fastq	66	66
# b	fastq	107	107
# b	fastq	957	957
# b	fastq	2777	2777
# b	fastq	1277	1277
# b	fastq	562	562
# b	fastq	480	480
# b	fastq	458	458
# b.U1_A10	fastq	664	664
# b.U1_B10	fastq	1793	1793
# b.V1_A10	fastq	379	379
# b.V1_B10	fastq	1071	1071
# b.U1_A10	fastq	664	664
# b.U1_B10	fastq	1793	1793
# b.V1_A10	fastq	379	379
# b.V1_B10	fastq	1071	1071
# b.U1_A10	fastq	664	664
# b.U1_B10	fastq	1793	1793
# b.V1_A10	fastq	379	379
# b.V1_B10	fastq	1071	1071
# b.U1_A10	fastq	664	664
# b.U1_B10	fastq	1793	1793
# b.V1_A10	fastq	379	379
# b.V1_B10	fastq	1071	1071
# b.U1_A10	fastq	8	8
# b.U1_B10	fastq	34	34
# b.V1_A10	fastq	11	11
# b.V1_B10	fastq	13	13
# b.U1_A10	fastq	16	16
# b.U1_B10	fastq	51	51
# b.V1_A10	fastq	13	13
# b.V1_B10	fastq	27	27
# b.U1_A10	fastq	81	81
# b.U1_B10	fastq	258	258
# b.V1_A10	fastq	131	131
# b.V1_B10	fastq	487	487
# b.U1_A10	fastq	559	559
# b.U1_B10	fastq	1450	1450
# b.V1_A10	fastq	224	224
# b.V1_B10	fastq	544	544
# b.U1_A10	fastq	254	254
# b.U1_B10	fastq	738	738
# b.V1_A10	fastq	79	79
# b.V1_B10	fastq	206	206
# b.U1_A10	fastq	122	122
# b.U1_B10	fastq	310	310
# b.V1_A10	fastq	35	35
# b.V1_B10	fastq	95	95
# b.U1_A10	fastq	101	101
# b.U1_B10	fastq	228	228
# b.V1_A10	fastq	53	53
# b.V1_B10	fastq	98	98
# b.U1_A10	fastq	82	82
# b.U1_B10	fastq	174	174
# b.V1_A10	fastq	57	57
# b.V1_B10	fastq	145	145
# [2021-03-05 10:02:44 INFO] Processed : 66
# [2021-03-05 10:02:44 INFO] Processed : 664
# [2021-03-05 10:02:44 INFO] Processed : 3907
# [2021-03-05 10:02:44 INFO] Processed : 1277
# [2021-03-05 10:02:44 INFO] Processed : 107
# [2021-03-05 10:02:45 INFO] Processed : 1793
# [2021-03-05 10:02:45 INFO] Processed : 3907
# [2021-03-05 10:02:45 INFO] Processed : 562
# [2021-03-05 10:02:45 INFO] Processed : 957
# [2021-03-05 10:02:45 INFO] Processed : 379
# [2021-03-05 10:02:45 INFO] Processed : 3907
# [2021-03-05 10:02:45 INFO] Processed : 480
# [2021-03-05 10:02:45 INFO] Processed : 2777
# [2021-03-05 10:02:45 INFO] Processed : 1071
# [2021-03-05 10:02:45 INFO] Processed : 3907
# [2021-03-05 10:02:45 INFO] Processed : 458
# [2021-03-05 10:02:45 INFO] Processed : 664
# [2021-03-05 10:02:45 INFO] Processed : 664
# [2021-03-05 10:02:45 INFO] Processed : 664
# [2021-03-05 10:02:45 INFO] Processed : 8
# [2021-03-05 10:02:45 INFO] Processed : 1793
# [2021-03-05 10:02:45 INFO] Processed : 1793
# [2021-03-05 10:02:45 INFO] Processed : 1793
# [2021-03-05 10:02:45 INFO] Processed : 34
# [2021-03-05 10:02:45 INFO] Processed : 379
# [2021-03-05 10:02:45 INFO] Processed : 379
# [2021-03-05 10:02:45 INFO] Processed : 379
# [2021-03-05 10:02:45 INFO] Processed : 11
# [2021-03-05 10:02:45 INFO] Processed : 1071
# [2021-03-05 10:02:45 INFO] Processed : 1071
# [2021-03-05 10:02:45 INFO] Processed : 13
# [2021-03-05 10:02:45 INFO] Processed : 1071
# [2021-03-05 10:02:45 INFO] Processed : 16
# [2021-03-05 10:02:45 INFO] Processed : 81
# [2021-03-05 10:02:45 INFO] Processed : 559
# [2021-03-05 10:02:45 INFO] Processed : 254
# [2021-03-05 10:02:45 INFO] Processed : 51
# [2021-03-05 10:02:45 INFO] Processed : 258
# [2021-03-05 10:02:45 INFO] Processed : 1450
# [2021-03-05 10:02:45 INFO] Processed : 738
# [2021-03-05 10:02:45 INFO] Processed : 13
# [2021-03-05 10:02:45 INFO] Processed : 131
# [2021-03-05 10:02:45 INFO] Processed : 224
# [2021-03-05 10:02:45 INFO] Processed : 79
# [2021-03-05 10:02:45 INFO] Processed : 27
# [2021-03-05 10:02:45 INFO] Processed : 487
# [2021-03-05 10:02:45 INFO] Processed : 544
# [2021-03-05 10:02:45 INFO] Processed : 206
# [2021-03-05 10:02:45 INFO] Processed : 122
# [2021-03-05 10:02:45 INFO] Processed : 101
# [2021-03-05 10:02:45 INFO] Processed : 82
# [2021-03-05 10:02:45 INFO] Processed : 310
# [2021-03-05 10:02:45 INFO] Processed : 228
# [2021-03-05 10:02:45 INFO] Processed : 174
# [2021-03-05 10:02:45 INFO] Processed : 35
# [2021-03-05 10:02:45 INFO] Processed : 53
# [2021-03-05 10:02:45 INFO] Processed : 57
# [2021-03-05 10:02:45 INFO] Processed : 95
# [2021-03-05 10:02:45 INFO] Processed : 98
# [2021-03-05 10:02:45 INFO] Processed : 145

# %%
# stat
# %reload_ext autoreload
# %autoreload 2
from qc import *
import qc

x = 'test/aaaaaa/b'
y = x + '/00.raw_data'
df = PiRNApipeStat(x).run()
df

# pd.DataFrame(columns=['A', 'B'])

# s1 = os.path.join('test', 'fx_stat.reads.csv')
# df1 = df.drop(['num_seqs', 'fx_type'], axis=1)
# df1 = df1.pivot_table(columns='u1a10', values='num_reads',
#                index=['sample', 'group'])
# df1.reset_index(inplace=True)
# df1 = df1.fillna(0)
# df1.to_csv(s1, index=False)
